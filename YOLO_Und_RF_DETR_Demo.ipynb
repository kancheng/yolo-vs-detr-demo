# %% [markdown]
# # YOLO & RF-DETR
#
#
# ## 中文
#
# ### YOLO 與 RF-DETR Demo 說明
#
# 本 Demo 展示了兩種主流目標檢測方法，YOLO 與 RF-DETR，並比較它們在同一張影像上的偵測結果。
#
# YOLO 是一種經典且高效率的即時目標檢測模型，特別適合需要快速推論的場景，例如工業檢測、監控系統與邊緣裝置部署。它的優點是速度快、部署方便，能在維持不錯準確率的同時提供即時反應能力。
#
# RF-DETR 則屬於 DETR 系列方法，結合 Transformer 架構進行端到端物件偵測。相較於傳統方法，它通常在複雜場景、密集目標或遮擋情況下有更穩定的表現。RF-DETR 的特點在於能更自然地建模全域資訊，減少後處理的依賴，並提升偵測結果的一致性。
#
# 在這個 Demo 中，使用者可以輸入影像，分別透過 YOLO 與 RF-DETR 進行推論，觀察兩者在偵測框位置、類別判斷與信心分數上的差異。這樣的比較有助於理解不同檢測架構在速度、精度與實務應用上的取捨。
#
# 此 Demo 的目的不只是展示模型效果，也希望幫助使用者快速建立對兩種方法的直觀認識，作為後續模型選型、研究分析與工程部署的參考。
#
# ## English
#
# ### YOLO and RF-DETR Demo Explanation
#
# This demo presents two mainstream object detection approaches, YOLO and RF-DETR, and compares their detection results on the same image.
#
# YOLO is a well-known real-time object detection model designed for high-speed inference. It is especially suitable for scenarios that require fast response, such as industrial inspection, surveillance systems, and edge-device deployment. Its main advantage is that it offers strong efficiency and practical deployment convenience while maintaining solid detection accuracy.
#
# RF-DETR, on the other hand, belongs to the DETR family and uses a Transformer-based architecture for end-to-end object detection. Compared with traditional approaches, it often performs more consistently in complex scenes, crowded objects, or occluded conditions. A key strength of RF-DETR is its ability to model global image information more naturally, reduce dependence on post-processing, and produce more coherent detection outputs.
#
# In this demo, users can input an image and run inference with both YOLO and RF-DETR, then directly observe the differences in bounding box placement, class prediction, and confidence scores. This side-by-side comparison helps illustrate the trade-offs between speed, accuracy, and practical application.
#
# The goal of this demo is not only to show model performance, but also to provide an intuitive understanding of these two detection paradigms for future model selection, research analysis, and engineering deployment.
#
# ## 日本語
#
# ### YOLO と RF-DETR のデモ説明
#
# このデモでは、代表的な物体検出手法である YOLO と RF-DETR を紹介し、同じ画像に対する検出結果を比較します。
#
# YOLO は、高速推論に優れたリアルタイム物体検出モデルとして広く知られています。工業検査、監視システム、エッジデバイス上での運用など、素早い応答が求められる場面に特に適しています。高い処理速度を持ちながら、実用的な精度も確保できる点が大きな特徴です。
#
# 一方、RF-DETR は DETR 系列に属する手法であり、Transformer ベースの構造を用いてエンドツーエンドの物体検出を行います。従来型の手法と比べて、複雑な背景、密集した物体、遮蔽のある状況でも、より安定した検出結果を示すことがあります。RF-DETR は画像全体の情報を自然に扱いやすく、後処理への依存を減らしながら、一貫性のある検出結果を得やすい点が特徴です。
#
# このデモでは、ユーザーが画像を入力し、YOLO と RF-DETR の両方で推論を実行することで、バウンディングボックスの位置、カテゴリ判定、信頼度スコアの違いを確認できます。この比較により、速度、精度、実運用上の使いやすさの違いを直感的に理解できます。
#
# このデモの目的は、単なるモデル性能の提示だけではなく、2 つの検出アプローチに対する理解を深め、今後のモデル選定、研究比較、実装検討に役立てることです。
#
# ## Français
#
# ### Explication de la démonstration YOLO et RF-DETR
#
# Cette démonstration présente deux approches courantes de détection d’objets, YOLO et RF-DETR, et compare leurs résultats de détection sur une même image.
#
# YOLO est un modèle classique de détection d’objets en temps réel, reconnu pour sa grande rapidité d’inférence. Il convient particulièrement aux situations où une réponse rapide est nécessaire, comme l’inspection industrielle, les systèmes de surveillance et le déploiement sur des appareils embarqués. Son principal avantage est de fournir une détection efficace et facile à déployer tout en conservant une bonne précision.
#
# RF-DETR, quant à lui, appartient à la famille DETR et repose sur une architecture Transformer pour effectuer une détection d’objets de bout en bout. Par rapport aux approches plus traditionnelles, il offre souvent des résultats plus stables dans des scènes complexes, avec des objets nombreux ou partiellement occultés. L’un de ses points forts est sa capacité à exploiter naturellement l’information globale de l’image, à réduire la dépendance au post-traitement et à produire des résultats plus cohérents.
#
# Dans cette démonstration, l’utilisateur peut fournir une image, exécuter l’inférence avec YOLO et RF-DETR, puis observer directement les différences concernant la position des boîtes englobantes, la classification et les scores de confiance. Cette comparaison permet de mieux comprendre les compromis entre vitesse, précision et usage pratique.
#
# L’objectif de cette démonstration n’est pas seulement de montrer les performances des modèles, mais aussi d’aider l’utilisateur à acquérir une compréhension intuitive de ces deux paradigmes de détection pour la sélection de modèles, l’analyse de recherche et le déploiement en ingénierie.
#
# ## Deutsch
#
# ### Erklärung zur YOLO- und RF-DETR-Demo
#
# Diese Demo zeigt zwei verbreitete Ansätze zur Objekterkennung, YOLO und RF-DETR, und vergleicht ihre Erkennungsergebnisse auf demselben Bild.
#
# YOLO ist ein bekanntes Echtzeit-Objekterkennungsmodell, das für besonders schnelle Inferenz entwickelt wurde. Es eignet sich vor allem für Anwendungen, bei denen eine schnelle Reaktion wichtig ist, zum Beispiel in der industriellen Inspektion, in Überwachungssystemen oder beim Einsatz auf Edge-Geräten. Sein größter Vorteil liegt in der hohen Geschwindigkeit und der praktischen Einsetzbarkeit bei gleichzeitig solider Genauigkeit.
#
# RF-DETR gehört dagegen zur DETR-Familie und nutzt eine Transformer-basierte Architektur für eine End-to-End-Objekterkennung. Im Vergleich zu klassischen Verfahren zeigt es oft stabilere Ergebnisse in komplexen Szenen, bei vielen Objekten oder bei Verdeckungen. Eine wichtige Stärke von RF-DETR ist die natürlichere Modellierung globaler Bildinformationen, wodurch die Abhängigkeit von Nachbearbeitung reduziert und konsistentere Erkennungsergebnisse erzielt werden können.
#
# In dieser Demo können Nutzer ein Bild eingeben und sowohl mit YOLO als auch mit RF-DETR eine Inferenz durchführen. Anschließend lassen sich Unterschiede bei den Bounding-Box-Positionen, den Klassenvorhersagen und den Konfidenzwerten direkt vergleichen. Dieser direkte Vergleich hilft dabei, die Unterschiede zwischen Geschwindigkeit, Genauigkeit und praktischer Nutzbarkeit besser zu verstehen.
#
# Das Ziel dieser Demo ist nicht nur die Darstellung der Modellleistung, sondern auch ein anschauliches Verständnis dieser beiden Erkennungsansätze als Grundlage für spätere Modellauswahl, Forschungsanalysen und technische Implementierung.

# %% [markdown]
# ## Install

# %%
# !pip install rfdetr
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 943.1 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.8/232.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.4/217.4 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## RF-DETR

# %%
import requests
import supervision as sv
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO
from rfdetr import RFDETRSegMedium
from rfdetr.assets.coco_classes import COCO_CLASSES

model = RFDETRSegMedium()

url = "https://ultralytics.com/images/bus.jpg"
response = requests.get(url, timeout=30)
response.raise_for_status()

image = Image.open(BytesIO(response.content)).convert("RGB")
detections = model.predict(image, threshold=0.5)

labels = [COCO_CLASSES[class_id] for class_id in detections.class_id]

mask_annotator = sv.MaskAnnotator()
label_annotator = sv.LabelAnnotator()

annotated_image = mask_annotator.annotate(image.copy(), detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)

plt.figure(figsize=(12, 8))
plt.imshow(annotated_image)
plt.axis("off")
plt.show()

annotated_image.save("rfdetr_result.png")
print("Saved: rfdetr_result.png")
# Out:
# [2026-03-25 07:04:24] [INFO] rf-detr - Downloading pretrained weights for rf-detr-seg-medium.pt
# rf-detr-seg-medium.pt:   0%|          | 0.00/136M [00:00<?, ?iB/s]
# [2026-03-25 07:04:32] [INFO] rf-detr - MD5 validation successful for rf-detr-seg-medium.pt
# [2026-03-25 07:04:32] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-25 07:04:32] [WARNING] rf-detr - Using patch size 12 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-25 07:04:33] [INFO] rf-detr - File rf-detr-seg-medium.pt already exists with correct MD5 hash.
# [2026-03-25 07:04:35] [WARNING] rf-detr - Model is not optimized for inference. Latency may be higher than expected. You can optimize the model for inference by calling model.optimize_for_inference().
# ...

# %% [markdown]
# ## YOLO

# %%
import requests
import matplotlib.pyplot as plt
from io import BytesIO
from PIL import Image
from ultralytics import YOLO

# Load model
model = YOLO("yolo26n-seg.pt")
# model = YOLO("path/to/best.pt")  # load a custom model

# Download image
url = "https://ultralytics.com/images/bus.jpg"
response = requests.get(url, timeout=30)
response.raise_for_status()
image = Image.open(BytesIO(response.content)).convert("RGB")

# Predict
results = model.predict(source=image)

# Show and save results
for i, result in enumerate(results):
    annotated_image = result.plot()

    plt.figure(figsize=(12, 8))
    plt.imshow(annotated_image)
    plt.axis("off")
    plt.show()

    Image.fromarray(annotated_image[..., ::-1]).save(f"yolo_result_{i}.png")
    print(f"Saved: yolo_result_{i}.png")

    if result.masks is not None:
        xy = result.masks.xy
        xyn = result.masks.xyn
        masks = result.masks.data

        print("Number of objects:", len(xy))
        print("Mask tensor shape:", masks.shape)
    else:
        print("No masks found.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
#
# 0: 640x480 4 persons, 1 bus, 212.2ms
# Speed: 18.3ms preprocess, 212.2ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 480)
# Saved: yolo_result_0.png
# Number of objects: 5
# Mask tensor shape: torch.Size([5, 640, 480])
